# %% [markdown]
# <a href="https://colab.research.google.com/github/Utpal-Mishra/Omdena-Nairobi-Local-Chapter-2021/blob/main/OmdenaNairobi2021Part4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import plotly.express as px
import plotly.graph_objects as go
from datetime import datetime as dt

# %% [markdown]
# ### Import Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **COVID-19 Cases**

# %% [markdown]
# ## **Import Dependencies**

# %% [markdown]
# ### Import File

# %%
import pandas as pd
path = '/content/drive/MyDrive/Omdena/Nairobi 2021/cases_by_age.csv'
data = pd.read_csv(path)
print("Data Shape: ", data.shape)
data.head()
# Out:
# Data Shape:  (7, 91)
#   Age_group  02-11-2021  01-11-2021  ...  07-08-2021  06-08-2021  05-08-2021
# 0       0-9           4           1  ...          33          59         NaN
# 1    Oct-19           1           0  ...          80         113         NaN
# 2     20-29          15           6  ...         234         285         NaN
# 3     30-39          13           8  ...         312         394         NaN
# 4     40-49          11           1  ...         209         294         NaN
#
# [5 rows x 91 columns]

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# ### Check Null Values

# %%
if data.isna().sum().sum() != 0:
  print("EMPTY VALUES EXIST IN THE DATA\n\nFollowing is a list of feature variable with their respective null values count:", data.isna().sum())
# Out:
# EMPTY VALUES EXIST IN THE DATA
#
# Following is a list of feature variable with their respective null values count: Age_group     0
# 02-11-2021    0
# 01-11-2021    0
# 31-10-2021    0
# 30-10-2021    0
#              ..
# 09-08-2021    0
# 08-08-2021    0
# 07-08-2021    0
# 06-08-2021    0
# 05-08-2021    7
# Length: 91, dtype: int64

# %%
data = data.fillna(0)   
data.isna().sum()
# Out:
# Age_group     0
# 02-11-2021    0
# 01-11-2021    0
# 31-10-2021    0
# 30-10-2021    0
#              ..
# 09-08-2021    0
# 08-08-2021    0
# 07-08-2021    0
# 06-08-2021    0
# 05-08-2021    0
# Length: 91, dtype: int64

# %% [markdown]
# ### Data Cleaning

# %%
data['Age_group'][1] = '10-19'
data.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Age_group  02-11-2021  01-11-2021  ...  07-08-2021  06-08-2021  05-08-2021
# 0       0-9           4           1  ...          33          59         0.0
# 1     10-19           1           0  ...          80         113         0.0
# 2     20-29          15           6  ...         234         285         0.0
# 3     30-39          13           8  ...         312         394         0.0
# 4     40-49          11           1  ...         209         294         0.0
#
# [5 rows x 91 columns]

# %%
# from google.colab import files

# # data.to_csv("new_master_data.csv")
# # files.download("new_master_data.csv")

# data.to_csv('new_master_data.csv')
# !cp new_master_data.csv "/content/drive/My Drive/Omdena/France 2021/Data/"

# %% [markdown]
# ## **Visualization**

# %% [markdown]
# **Plotting Function**

# %%
def barplot(data):
  fig = px.bar(data, x=data.Age_group, y=data.Cases, animation_frame = data.Date, color=data.Age_group, barmode='group')
  fig.update_xaxes(title_text = "Age Categories", rangeslider_visible=True, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'COVID-19 Cases', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=350, width=800, title_text='Witnessed COVID-19 Cases For Different Age Groups') 
  fig.show()

# %%
data = data.melt(id_vars=["Age_group"], var_name = "Date", value_name = "Cases")
data = data[['Date', 'Age_group', 'Cases']]
data = data[data.Date != ' Science/data_pdfs/Press-Statement-on-Poland-Donation-September-13-2021']
data.sort_values(["Date", 'Age_group'], inplace = True)
data.head()
# Out:
#            Date Age_group  Cases
# 434  01-09-2021       0-9   34.0
# 435  01-09-2021     10-19   76.0
# 436  01-09-2021     20-29  157.0
# 437  01-09-2021     30-39  229.0
# 438  01-09-2021     40-49  177.0

# %%
barplot(data)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8aeef435-516a-4945-8ae7-cfa9d044911d" class="plotly-graph-div" style="height:350px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8aeef435-516a-4945-8ae7-cfa9d044911d")) {
#                     Plotly.newPlot(
#                         '8aeef435-516a-4945-8ae7-cfa9d044911d',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_group=%{x}<br>Date=01-09-2021<br>Cases=%{y}", "legendgroup": "Age_group=0-9", "marker": {"color": "#636efa"}, "name": "Age_group=0-9", "offsetgroup": "Age_group=0-9", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["0-9"], "xaxis": "x", "y": [34.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_group=%{x}<br>Date=01-09-2021<br>Cases=%{y}", "legendgroup": "Age_group=10-19", "marker": {"color": "#EF553B"}, "name": "Age_group=10-19", "offsetgroup": "Age_group=10-19", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["10-19"], "xaxis": "x", "y": [76.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_group=%{x}<br>Date=01-09-2021<br>Cases=%{y}", "legendgroup": "Age_group=20-29", "marker": {"color": "#00cc96"}, "name": "Age_group=20-29", "offsetgroup": "Age_group=20-29", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["20-29"], "xaxis": "x", "y": [157.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_group=%{x}<br>Date=01-09-2021<br>Cases=%{y}", "legendgroup": "Age_group=30-39", "marker": {"color": "#ab63fa"}, "name": "Age_group=30-39", "offsetgroup": "Age_group=30-39", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["30-39"], "xaxis": "x", "y": [229.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_group=%{x}<br>Date=01-09-2021<br>Cases=%{y}", "legendgroup": "Age_group=40-49", "marker": {"color": "#FFA15A"}, "name": "Age_group=40-49", "offsetgroup": "Age_group=40-49", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["40-49"], "xaxis": "x", "y": [177.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_group=%{x}<br>Date=01-09-2021<br>Cases=%{y}", "legendgroup": "Age_group=50-59", "marker": {"color": "#19d3f3"}, "name": "Age_group=50-59", "offsetgroup": "Age_group=50-59", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["50-59"], "xaxis": "x", "y": [137.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_group=%{x}<br>Date=01-09-2021<br>Cases=%{y}", "legendgroup": "Age_group=60+", "marker": {"color": "#FF6692"}, "name": "Age_group=60+", "offsetgroup": "Age_group=60+", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["60+"], "xaxis": "x", "y": [208.0], "yaxis": "y"}],
#                         {"barmode": "group", "height": 350, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "sliders": [{"active": 0, "currentvalue": {"prefix": "Date="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["01-09-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "01-09-2021", "method": "animate"}, {"args": [["01-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "01-10-2021", "method": "animate"}, {"args": [["01-11-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "01-11-2021", "method": "animate"}, {"args": [["02-09-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "02-09-2021", "method": "animate"}, {"args": [["02-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "02-10-2021", "method": "animate"}, {"args": [["02-11-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "02-11-2021", "method": "animate"}, {"args": [["03-09-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "03-09-2021", "method": "animate"}, {"args": [["03-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "03-10-2021", "method": "animate"}, {"args": [["04-09-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "04-09-2021", "method": "animate"}, {"args": [["04-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "04-10-2021", "method": "animate"}, {"args": [["05-08-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "05-08-2021", "method": "animate"}, {"args": [["05-09-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "05-09-2021", "method": "animate"}, {"args": [["05-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "05-10-2021", "method": "animate"}, {"args": [["06-08-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "06-08-2021", "method": "animate"}, {"args": [["06-09-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "06-09-2021", "method": "animate"}, {"args": [["06-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "06-10-2021", "method": "animate"}, {"args": [["07-08-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "07-08-2021", "method": "animate"}, {"args": [["07-09-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "07-09-2021", "method": "animate"}, {"args": [["0 ...

# %%
data = data[['Age_group', 'Cases']].groupby('Age_group').sum()
data = data.reset_index()
fig = go.Figure(data=[go.Pie(labels=data.Age_group, values=data.Cases, hole=.5)])
fig.update_layout(height=500, width=1400, title_text='% of COVID-19 Cases For Different Age Groups') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="dd3d3e1e-f71f-4724-afb5-bd85d01d05db" class="plotly-graph-div" style="height:500px; width:1400px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dd3d3e1e-f71f-4724-afb5-bd85d01d05db")) {
#                     Plotly.newPlot(
#                         'dd3d3e1e-f71f-4724-afb5-bd85d01d05db',
#                         [{"hole": 0.5, "labels": ["0-9", "10-19", "20-29", "30-39", "40-49", "50-59", "60+"], "type": "pie", "values": [1344.0, 2766.0, 6149.0, 8434.0, 6359.0, 4887.0, 6893.0]}],
#                         {"height": 500, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker":  ...

# %% [markdown]
# # **COVID-19 Fatilities**

# %% [markdown]
# ## **Import Dependencies**

# %% [markdown]
# ### Import File

# %%
import pandas as pd
path = '/content/drive/MyDrive/Omdena/Nairobi 2021/fatalities.csv'
data = pd.read_csv(path)
print("Data Shape: ", data.shape)
data.head()
# Out:
# Data Shape:  (7, 91)
#   Age_Group  02-11-2021  01-11-2021  ...  07-08-2021  06-08-2021  05-08-2021
# 0       0-9           0           0  ...           0           0         NaN
# 1    Oct-19           0           0  ...           0           0         NaN
# 2     20-29           0           0  ...           1           0         NaN
# 3     30-39           0           0  ...           0           2         NaN
# 4     40-49           0           0  ...           3           1         NaN
#
# [5 rows x 91 columns]

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# ### Check Null Values

# %%
if data.isna().sum().sum() != 0:
  print("EMPTY VALUES EXIST IN THE DATA\n\nFollowing is a list of feature variable with their respective null values count:", data.isna().sum())
# Out:
# EMPTY VALUES EXIST IN THE DATA
#
# Following is a list of feature variable with their respective null values count: Age_Group     0
# 02-11-2021    0
# 01-11-2021    0
# 31-10-2021    0
# 30-10-2021    0
#              ..
# 09-08-2021    0
# 08-08-2021    0
# 07-08-2021    0
# 06-08-2021    0
# 05-08-2021    7
# Length: 91, dtype: int64

# %%
data = data.fillna(0)   
data.isna().sum()
# Out:
# Age_Group     0
# 02-11-2021    0
# 01-11-2021    0
# 31-10-2021    0
# 30-10-2021    0
#              ..
# 09-08-2021    0
# 08-08-2021    0
# 07-08-2021    0
# 06-08-2021    0
# 05-08-2021    0
# Length: 91, dtype: int64

# %% [markdown]
# ### Data Cleaning

# %%
data['Age_Group'][1] = '10-19'
data.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Age_Group  02-11-2021  01-11-2021  ...  07-08-2021  06-08-2021  05-08-2021
# 0       0-9           0           0  ...           0           0         0.0
# 1     10-19           0           0  ...           0           0         0.0
# 2     20-29           0           0  ...           1           0         0.0
# 3     30-39           0           0  ...           0           2         0.0
# 4     40-49           0           0  ...           3           1         0.0
#
# [5 rows x 91 columns]

# %%
# from google.colab import files

# # data.to_csv("new_master_data.csv")
# # files.download("new_master_data.csv")

# data.to_csv('new_master_data.csv')
# !cp new_master_data.csv "/content/drive/My Drive/Omdena/France 2021/Data/"

# %% [markdown]
# ## **Visualization**

# %% [markdown]
# **Plotting Function**

# %%
def barplot(data):
  fig = px.bar(data, x=data.Age_Group, y=data.Cases, animation_frame = data.Date, color=data.Age_Group, barmode='group')
  fig.update_xaxes(title_text = "Age Categories", rangeslider_visible=True, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'COVID-19 Fatalities', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=350, width=800, title_text='Witnessed COVID-19 Fatalities For Different Age Groups') 
  fig.show()

# %%
data = data.melt(id_vars=["Age_Group"], var_name = "Date", value_name = "Cases")
data = data[['Date', 'Age_Group', 'Cases']]
data = data[data.Date != ' Science/data_pdfs/Press-Statement-on-Poland-Donation-September-13-2021']
data.sort_values(["Date", 'Age_Group'], inplace = True)
#data.head()

# %%
barplot(data)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a8738403-35dd-4e72-b27c-7efcb1959366" class="plotly-graph-div" style="height:350px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a8738403-35dd-4e72-b27c-7efcb1959366")) {
#                     Plotly.newPlot(
#                         'a8738403-35dd-4e72-b27c-7efcb1959366',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_Group=%{x}<br>Date=01-09-2021<br>Cases=%{y}", "legendgroup": "Age_Group=0-9", "marker": {"color": "#636efa"}, "name": "Age_Group=0-9", "offsetgroup": "Age_Group=0-9", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["0-9"], "xaxis": "x", "y": [0.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_Group=%{x}<br>Date=01-09-2021<br>Cases=%{y}", "legendgroup": "Age_Group=10-19", "marker": {"color": "#EF553B"}, "name": "Age_Group=10-19", "offsetgroup": "Age_Group=10-19", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["10-19"], "xaxis": "x", "y": [0.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_Group=%{x}<br>Date=01-09-2021<br>Cases=%{y}", "legendgroup": "Age_Group=20-29", "marker": {"color": "#00cc96"}, "name": "Age_Group=20-29", "offsetgroup": "Age_Group=20-29", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["20-29"], "xaxis": "x", "y": [0.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_Group=%{x}<br>Date=01-09-2021<br>Cases=%{y}", "legendgroup": "Age_Group=30-39", "marker": {"color": "#ab63fa"}, "name": "Age_Group=30-39", "offsetgroup": "Age_Group=30-39", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["30-39"], "xaxis": "x", "y": [2.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_Group=%{x}<br>Date=01-09-2021<br>Cases=%{y}", "legendgroup": "Age_Group=40-49", "marker": {"color": "#FFA15A"}, "name": "Age_Group=40-49", "offsetgroup": "Age_Group=40-49", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["40-49"], "xaxis": "x", "y": [0.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_Group=%{x}<br>Date=01-09-2021<br>Cases=%{y}", "legendgroup": "Age_Group=50-59", "marker": {"color": "#19d3f3"}, "name": "Age_Group=50-59", "offsetgroup": "Age_Group=50-59", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["50-59"], "xaxis": "x", "y": [4.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_Group=%{x}<br>Date=01-09-2021<br>Cases=%{y}", "legendgroup": "Age_Group=60+", "marker": {"color": "#FF6692"}, "name": "Age_Group=60+", "offsetgroup": "Age_Group=60+", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["60+"], "xaxis": "x", "y": [7.0], "yaxis": "y"}],
#                         {"barmode": "group", "height": 350, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "sliders": [{"active": 0, "currentvalue": {"prefix": "Date="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["01-09-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "01-09-2021", "method": "animate"}, {"args": [["01-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "01-10-2021", "method": "animate"}, {"args": [["01-11-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "01-11-2021", "method": "animate"}, {"args": [["02-09-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "02-09-2021", "method": "animate"}, {"args": [["02-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "02-10-2021", "method": "animate"}, {"args": [["02-11-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "02-11-2021", "method": "animate"}, {"args": [["03-09-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "03-09-2021", "method": "animate"}, {"args": [["03-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "03-10-2021", "method": "animate"}, {"args": [["04-09-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "04-09-2021", "method": "animate"}, {"args": [["04-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "04-10-2021", "method": "animate"}, {"args": [["05-08-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "05-08-2021", "method": "animate"}, {"args": [["05-09-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "05-09-2021", "method": "animate"}, {"args": [["05-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "05-10-2021", "method": "animate"}, {"args": [["06-08-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "06-08-2021", "method": "animate"}, {"args": [["06-09-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "06-09-2021", "method": "animate"}, {"args": [["06-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "06-10-2021", "method": "animate"}, {"args": [["07-08-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "07-08-2021", "method": "animate"}, {"args": [["07-09-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "07-09-2021", "method": "animate"}, {"args": [["0 ...

# %%
data = data[['Age_Group', 'Cases']].groupby('Age_Group').sum()
data = data.reset_index()
fig = go.Figure(data=[go.Pie(labels=data.Age_Group, values=data.Cases, hole=.5)])
fig.update_layout(height=500, width=1400, title_text='% of COVID-19 Fatalities For Different Age Groups') 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ec5de258-c3c9-43ca-acef-3b34dae56474" class="plotly-graph-div" style="height:500px; width:1400px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ec5de258-c3c9-43ca-acef-3b34dae56474")) {
#                     Plotly.newPlot(
#                         'ec5de258-c3c9-43ca-acef-3b34dae56474',
#                         [{"hole": 0.5, "labels": ["0-9", "10-19", "20-29", "30-39", "40-49", "50-59", "60+"], "type": "pie", "values": [1.0, 5.0, 14.0, 51.0, 104.0, 144.0, 646.0]}],
#                         {"height": 500, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker":  ...
