# %% [markdown]
# <a href="https://colab.research.google.com/github/Utpal-Mishra/Omdena-Nairobi-Local-Chapter-2021/blob/main/OmdenaNairobi2021Part4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import plotly.express as px
from datetime import datetime as dt

# %% [markdown]
# ### Import Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **COVID-19 Cases**

# %% [markdown]
# ## **Import Dependencies**

# %% [markdown]
# ### Import File

# %%
import pandas as pd
path = '/content/drive/MyDrive/Omdena/Nairobi 2021/cases_by_age.csv'
data = pd.read_csv(path)
print("Data Shape: ", data.shape)
data.head()
# Out:
# Data Shape:  (7, 91)
#   Age_group  02-11-2021  01-11-2021  ...  07-08-2021  06-08-2021  05-08-2021
# 0       0-9           4           1  ...          33          59         NaN
# 1    Oct-19           1           0  ...          80         113         NaN
# 2     20-29          15           6  ...         234         285         NaN
# 3     30-39          13           8  ...         312         394         NaN
# 4     40-49          11           1  ...         209         294         NaN
#
# [5 rows x 91 columns]

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# ### Check Null Values

# %%
if data.isna().sum().sum() != 0:
  print("EMPTY VALUES EXIST IN THE DATA\n\nFollowing is a list of feature variable with their respective null values count:", data.isna().sum())
# Out:
# EMPTY VALUES EXIST IN THE DATA
#
# Following is a list of feature variable with their respective null values count: Age_group     0
# 02-11-2021    0
# 01-11-2021    0
# 31-10-2021    0
# 30-10-2021    0
#              ..
# 09-08-2021    0
# 08-08-2021    0
# 07-08-2021    0
# 06-08-2021    0
# 05-08-2021    7
# Length: 91, dtype: int64

# %%
data = data.fillna(0)   
data.isna().sum()
# Out:
# Age_group     0
# 02-11-2021    0
# 01-11-2021    0
# 31-10-2021    0
# 30-10-2021    0
#              ..
# 09-08-2021    0
# 08-08-2021    0
# 07-08-2021    0
# 06-08-2021    0
# 05-08-2021    0
# Length: 91, dtype: int64

# %% [markdown]
# ### Data Cleaning

# %%
data['Age_group'][1] = '10-19'
data.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Age_group  02-11-2021  01-11-2021  ...  07-08-2021  06-08-2021  05-08-2021
# 0       0-9           4           1  ...          33          59         0.0
# 1     10-19           1           0  ...          80         113         0.0
# 2     20-29          15           6  ...         234         285         0.0
# 3     30-39          13           8  ...         312         394         0.0
# 4     40-49          11           1  ...         209         294         0.0
#
# [5 rows x 91 columns]

# %%
# from google.colab import files

# # data.to_csv("new_master_data.csv")
# # files.download("new_master_data.csv")

# data.to_csv('new_master_data.csv')
# !cp new_master_data.csv "/content/drive/My Drive/Omdena/France 2021/Data/"

# %% [markdown]
# ## **Visualization**

# %% [markdown]
# **Plotting Function**

# %%
def barplot(data):
  fig = px.bar(data, x=data.Age_group, y=data.Cases, animation_frame = data.Date, color=data.Age_group, barmode='group')
  fig.update_xaxes(title_text = "Age Categories", rangeslider_visible=True, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'COVID-19 Cases', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=700, width=1400, title_text='Witnessed COVID-19 Cases For Different Age Groups') 
  fig.show()

# %%
data = data.melt(id_vars=["Age_group"], var_name = "Date", value_name = "Cases")
data = data[['Date', 'Age_group', 'Cases']]
data = data[data.Date != ' Science/data_pdfs/Press-Statement-on-Poland-Donation-September-13-2021']
#data.sort_values(["Date"], inplace = True)
data.head()
# Out:
#          Date Age_group  Cases
# 0  02-11-2021       0-9    4.0
# 1  02-11-2021     10-19    1.0
# 2  02-11-2021     20-29   15.0
# 3  02-11-2021     30-39   13.0
# 4  02-11-2021     40-49   11.0

# %%
barplot(data)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cf3e9f15-8847-43b0-b317-631414762ce5" class="plotly-graph-div" style="height:700px; width:1400px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cf3e9f15-8847-43b0-b317-631414762ce5")) {
#                     Plotly.newPlot(
#                         'cf3e9f15-8847-43b0-b317-631414762ce5',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_group=%{x}<br>Date=02-11-2021<br>Cases=%{y}", "legendgroup": "Age_group=0-9", "marker": {"color": "#636efa"}, "name": "Age_group=0-9", "offsetgroup": "Age_group=0-9", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["0-9"], "xaxis": "x", "y": [4.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_group=%{x}<br>Date=02-11-2021<br>Cases=%{y}", "legendgroup": "Age_group=10-19", "marker": {"color": "#EF553B"}, "name": "Age_group=10-19", "offsetgroup": "Age_group=10-19", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["10-19"], "xaxis": "x", "y": [1.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_group=%{x}<br>Date=02-11-2021<br>Cases=%{y}", "legendgroup": "Age_group=20-29", "marker": {"color": "#00cc96"}, "name": "Age_group=20-29", "offsetgroup": "Age_group=20-29", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["20-29"], "xaxis": "x", "y": [15.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_group=%{x}<br>Date=02-11-2021<br>Cases=%{y}", "legendgroup": "Age_group=30-39", "marker": {"color": "#ab63fa"}, "name": "Age_group=30-39", "offsetgroup": "Age_group=30-39", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["30-39"], "xaxis": "x", "y": [13.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_group=%{x}<br>Date=02-11-2021<br>Cases=%{y}", "legendgroup": "Age_group=40-49", "marker": {"color": "#FFA15A"}, "name": "Age_group=40-49", "offsetgroup": "Age_group=40-49", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["40-49"], "xaxis": "x", "y": [11.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_group=%{x}<br>Date=02-11-2021<br>Cases=%{y}", "legendgroup": "Age_group=50-59", "marker": {"color": "#19d3f3"}, "name": "Age_group=50-59", "offsetgroup": "Age_group=50-59", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["50-59"], "xaxis": "x", "y": [12.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_group=%{x}<br>Date=02-11-2021<br>Cases=%{y}", "legendgroup": "Age_group=60+", "marker": {"color": "#FF6692"}, "name": "Age_group=60+", "offsetgroup": "Age_group=60+", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["60+"], "xaxis": "x", "y": [14.0], "yaxis": "y"}],
#                         {"barmode": "group", "height": 700, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "sliders": [{"active": 0, "currentvalue": {"prefix": "Date="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["02-11-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "02-11-2021", "method": "animate"}, {"args": [["01-11-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "01-11-2021", "method": "animate"}, {"args": [["31-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "31-10-2021", "method": "animate"}, {"args": [["30-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "30-10-2021", "method": "animate"}, {"args": [["29-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "29-10-2021", "method": "animate"}, {"args": [["28-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "28-10-2021", "method": "animate"}, {"args": [["27-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "27-10-2021", "method": "animate"}, {"args": [["26-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "26-10-2021", "method": "animate"}, {"args": [["25-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "25-10-2021", "method": "animate"}, {"args": [["24-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "24-10-2021", "method": "animate"}, {"args": [["23-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "23-10-2021", "method": "animate"}, {"args": [["22-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "22-10-2021", "method": "animate"}, {"args": [["21-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "21-10-2021", "method": "animate"}, {"args": [["20-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "20-10-2021", "method": "animate"}, {"args": [["19-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "19-10-2021", "method": "animate"}, {"args": [["18-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "18-10-2021", "method": "animate"}, {"args": [["17-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "17-10-2021", "method": "animate"}, {"args": [["16-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "16-10-2021", "method": "animate"}, {"args": [["1 ...

# %% [markdown]
# # **COVID-19 Fatilities**

# %% [markdown]
# ## **Import Dependencies**

# %% [markdown]
# ### Import File

# %%
import pandas as pd
path = '/content/drive/MyDrive/Omdena/Nairobi 2021/fatalities.csv'
data = pd.read_csv(path)
print("Data Shape: ", data.shape)
data.head()
# Out:
# Data Shape:  (7, 91)
#   Age_Group  02-11-2021  01-11-2021  ...  07-08-2021  06-08-2021  05-08-2021
# 0       0-9           0           0  ...           0           0         NaN
# 1    Oct-19           0           0  ...           0           0         NaN
# 2     20-29           0           0  ...           1           0         NaN
# 3     30-39           0           0  ...           0           2         NaN
# 4     40-49           0           0  ...           3           1         NaN
#
# [5 rows x 91 columns]

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# ### Check Null Values

# %%
if data.isna().sum().sum() != 0:
  print("EMPTY VALUES EXIST IN THE DATA\n\nFollowing is a list of feature variable with their respective null values count:", data.isna().sum())
# Out:
# EMPTY VALUES EXIST IN THE DATA
#
# Following is a list of feature variable with their respective null values count: Age_Group     0
# 02-11-2021    0
# 01-11-2021    0
# 31-10-2021    0
# 30-10-2021    0
#              ..
# 09-08-2021    0
# 08-08-2021    0
# 07-08-2021    0
# 06-08-2021    0
# 05-08-2021    7
# Length: 91, dtype: int64

# %%
data = data.fillna(0)   
data.isna().sum()
# Out:
# Age_Group     0
# 02-11-2021    0
# 01-11-2021    0
# 31-10-2021    0
# 30-10-2021    0
#              ..
# 09-08-2021    0
# 08-08-2021    0
# 07-08-2021    0
# 06-08-2021    0
# 05-08-2021    0
# Length: 91, dtype: int64

# %% [markdown]
# ### Data Cleaning

# %%
data['Age_Group'][1] = '10-19'
data.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Age_Group  02-11-2021  01-11-2021  ...  07-08-2021  06-08-2021  05-08-2021
# 0       0-9           0           0  ...           0           0         0.0
# 1     10-19           0           0  ...           0           0         0.0
# 2     20-29           0           0  ...           1           0         0.0
# 3     30-39           0           0  ...           0           2         0.0
# 4     40-49           0           0  ...           3           1         0.0
#
# [5 rows x 91 columns]

# %%
# from google.colab import files

# # data.to_csv("new_master_data.csv")
# # files.download("new_master_data.csv")

# data.to_csv('new_master_data.csv')
# !cp new_master_data.csv "/content/drive/My Drive/Omdena/France 2021/Data/"

# %% [markdown]
# ## **Visualization**

# %% [markdown]
# **Plotting Function**

# %%
def barplot(data):
  fig = px.bar(data, x=data.Age_Group, y=data.Cases, animation_frame = data.Date, color=data.Age_Group, barmode='group')
  fig.update_xaxes(title_text = "Age Categories", rangeslider_visible=True, showline=True, linewidth=2, linecolor='black', mirror=True)
  fig.update_yaxes(title_text = 'COVID-19 Fatalities', showline=True, linewidth=2, linecolor='black', mirror=True)
  # fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)', marker_line_width=1.5, opacity=0.6)
  fig.update_layout(height=700, width=1400, title_text='Witnessed COVID-19 Fatalities For Different Age Groups') 
  fig.show()

# %%
data = data.melt(id_vars=["Age_Group"], var_name = "Date", value_name = "Cases")
data = data[['Date', 'Age_Group', 'Cases']]
data = data[data.Date != ' Science/data_pdfs/Press-Statement-on-Poland-Donation-September-13-2021']
data.sort_values(["Date"], inplace = True)
data.head()
# Out:
#          Date Age_Group  Cases
# 0  02-11-2021       0-9    0.0
# 1  02-11-2021     10-19    0.0
# 2  02-11-2021     20-29    0.0
# 3  02-11-2021     30-39    0.0
# 4  02-11-2021     40-49    0.0

# %%
barplot(data)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8c857187-74c8-47f9-bfe4-10ecadbe9cbf" class="plotly-graph-div" style="height:700px; width:1400px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8c857187-74c8-47f9-bfe4-10ecadbe9cbf")) {
#                     Plotly.newPlot(
#                         '8c857187-74c8-47f9-bfe4-10ecadbe9cbf',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_Group=%{x}<br>Date=02-11-2021<br>Cases=%{y}", "legendgroup": "Age_Group=0-9", "marker": {"color": "#636efa"}, "name": "Age_Group=0-9", "offsetgroup": "Age_Group=0-9", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["0-9"], "xaxis": "x", "y": [0.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_Group=%{x}<br>Date=02-11-2021<br>Cases=%{y}", "legendgroup": "Age_Group=10-19", "marker": {"color": "#EF553B"}, "name": "Age_Group=10-19", "offsetgroup": "Age_Group=10-19", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["10-19"], "xaxis": "x", "y": [0.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_Group=%{x}<br>Date=02-11-2021<br>Cases=%{y}", "legendgroup": "Age_Group=20-29", "marker": {"color": "#00cc96"}, "name": "Age_Group=20-29", "offsetgroup": "Age_Group=20-29", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["20-29"], "xaxis": "x", "y": [0.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_Group=%{x}<br>Date=02-11-2021<br>Cases=%{y}", "legendgroup": "Age_Group=30-39", "marker": {"color": "#ab63fa"}, "name": "Age_Group=30-39", "offsetgroup": "Age_Group=30-39", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["30-39"], "xaxis": "x", "y": [0.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_Group=%{x}<br>Date=02-11-2021<br>Cases=%{y}", "legendgroup": "Age_Group=40-49", "marker": {"color": "#FFA15A"}, "name": "Age_Group=40-49", "offsetgroup": "Age_Group=40-49", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["40-49"], "xaxis": "x", "y": [0.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_Group=%{x}<br>Date=02-11-2021<br>Cases=%{y}", "legendgroup": "Age_Group=50-59", "marker": {"color": "#19d3f3"}, "name": "Age_Group=50-59", "offsetgroup": "Age_Group=50-59", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["50-59"], "xaxis": "x", "y": [0.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Age_Group=%{x}<br>Date=02-11-2021<br>Cases=%{y}", "legendgroup": "Age_Group=60+", "marker": {"color": "#FF6692"}, "name": "Age_Group=60+", "offsetgroup": "Age_Group=60+", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["60+"], "xaxis": "x", "y": [1.0], "yaxis": "y"}],
#                         {"barmode": "group", "height": 700, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "sliders": [{"active": 0, "currentvalue": {"prefix": "Date="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["02-11-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "02-11-2021", "method": "animate"}, {"args": [["01-11-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "01-11-2021", "method": "animate"}, {"args": [["31-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "31-10-2021", "method": "animate"}, {"args": [["30-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "30-10-2021", "method": "animate"}, {"args": [["29-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "29-10-2021", "method": "animate"}, {"args": [["28-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "28-10-2021", "method": "animate"}, {"args": [["27-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "27-10-2021", "method": "animate"}, {"args": [["26-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "26-10-2021", "method": "animate"}, {"args": [["25-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "25-10-2021", "method": "animate"}, {"args": [["24-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "24-10-2021", "method": "animate"}, {"args": [["23-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "23-10-2021", "method": "animate"}, {"args": [["22-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "22-10-2021", "method": "animate"}, {"args": [["21-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "21-10-2021", "method": "animate"}, {"args": [["20-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "20-10-2021", "method": "animate"}, {"args": [["19-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "19-10-2021", "method": "animate"}, {"args": [["18-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "18-10-2021", "method": "animate"}, {"args": [["17-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "17-10-2021", "method": "animate"}, {"args": [["16-10-2021"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "16-10-2021", "method": "animate"}, {"args": [["1 ...
